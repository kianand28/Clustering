# %% [markdown]
# ## Perform clustering (hierarchical, K means clustering and DBSCAN) for the airlines data to obtain optimum number of clusters.
# ## Draw the inferences from the clusters obtained.

# %% [markdown]
# ###  Importing Required Libraries & Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import normalize

# %%
xls = pd.ExcelFile("C:\Vishal\ExcelR\Data Science\Assignments\EastWestAirlines.xlsx")

# %%
airline = pd.read_excel(xls, 'data')
airline.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %% [markdown]
# ### Exploratory Data Analysis

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline = airline.drop(['ID#'],axis=1)
airline
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline = airline.rename(columns={'Award?':'Award'})

# %%
airline_norm = pd.DataFrame(normalize(airline), columns=airline.columns)
airline_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ## Hierarchical clustering

# %%
airline_norm1 = airline_norm.copy()

# %%
plt.figure(figsize=(10, 7))  
dendograms=sch.dendrogram(sch.linkage(airline_norm1,'complete'))

# %%
# Create Clusters (y)
hclusters=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')
hclusters
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
y=pd.DataFrame(hclusters.fit_predict(airline_norm1),columns=['Clustersid'])
y['Clustersid'].value_counts()
# Out:
# 2    1547
# 4    1191
# 3     579
# 1     453
# 0     229
# Name: Clustersid, dtype: int64

# %%
# Creating a copy of dataset
airline1 = airline.copy()
# Adding clusters to dataset
airline1['Clustersid']=hclusters.labels_
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline1.groupby('Clustersid').agg(['mean']).reset_index()
# Out:
#   Clustersid       Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                       mean        mean      mean      mean      mean
# 0          0   5524.222707    8.755459  1.000000  1.000000  1.000000
# 1          1  31066.514349  111.415011  3.200883  1.026490  1.070640
# 2          2  81201.080802  136.521008  2.115061  1.013575  1.000646
# 3          3  69569.894646   97.257340  3.326425  1.032815  1.022453
# 4          4  94957.590260  215.220823  1.141058  1.005038  1.002519
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0    584.532751    2.401747         66.982533        0.209607
# 1  40266.935982   17.289183        626.754967        1.812362
# 2  16350.149968   13.574014        488.550743        1.340659
# 3  35743.675302   17.784111        406.804836        1.274611
# 4   3524.928631    5.640638        461.104954        1.521411
#
#   Days_since_enroll     Award
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 5))  
plt.scatter(airline1['Clustersid'],airline1['Balance'], c=hclusters.labels_)

# %% [markdown]
# ## k-means Clustering

# %% [markdown]
# ### Importing Libraries for k-means & creating copy of datasets

# %%
from sklearn.cluster import KMeans

# %%
airline2 = airline.copy()
airline_norm2 = airline_norm.copy()

# %%
# Using within-cluster sum-of-squares criterion (WCSS) 
wcss=[]
for i in range (1,11):
    kmeans=KMeans(n_clusters=i,random_state=2)
    kmeans.fit(airline_norm2)
    wcss.append(kmeans.inertia_)

# %%
# Plot K values range vs WCSS to get Elbow graph for choosing K (No. of Clusters)
plt.plot(range(1,11),wcss)
plt.title('Elbow Graph')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### Building cluster using k = 4

# %%
# Cluster algorithm using K=4
clusters_4=KMeans(4,random_state=30).fit(airline_norm2)
clusters_4
# Out:
# KMeans(n_clusters=4, random_state=30)

# %%
clusters_4.labels_
# Out:
# array([0, 0, 0, ..., 3, 0, 0])

# %%
# Assigning clusters to the original data set
airline2['Clusters_4_ID']=clusters_4.labels_
airline2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Computing the centroids for K=4 clusters with 11 variables
clusters_4.cluster_centers_
# Out:
# array([[9.82878899e-01, 3.71612347e-03, 4.15057209e-05, 3.77179195e-05,
#         3.76205578e-05, 8.06914054e-02, 1.57453088e-04, 6.65079627e-03,
#         2.12921781e-05, 1.03324885e-01, 4.81770304e-06],
#        [5.23653977e-01, 2.37603195e-03, 9.13653056e-05, 4.56081254e-05,
#         4.45095230e-05, 7.97866700e-01, 5.07019477e-04, 1.75075997e-02,
#         5.89123100e-05, 1.31443994e-01, 3.00837174e-05],
#        [6.28081328e-01, 9.30359261e-04, 2.06331617e-04, 2.06128767e-04,
#         2.05879951e-04, 1.23980626e-01, 4.76413717e-04, 6.66146530e-03,
#         2.24385615e-05, 6.89106611e-01, 2.58980762e-05],
#        [8.99048678e-01, 2.03403471e-03, 5.68074076e-05, 3.01913199e-05,
#         2.95156437e-05, 4.03089039e-01, 4.02398112e-04, 7.62262675e-03,
#         2.24052643e-05, 8.50654942e-02, 9.73901648e-06]])

# %%
# Grouping data by Clusters (k=4)
airline2.groupby('Clusters_4_ID').agg(['mean']).reset_index()
# Out:
#   Clusters_4_ID       Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                          mean        mean      mean      mean      mean
# 0             0  88484.857577  175.062961  1.495441  1.008250  1.001737
# 1             1  28617.579670  112.000000  3.280220  1.030220  1.068681
# 2             2   5129.247934    8.285124  1.004132  1.004132  1.000000
# 3             3  72378.903670  119.606422  3.077982  1.024771  1.018349
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0   8110.131568    8.770734        476.973079        1.439427
# 1  42166.565934   17.634615        659.725275        1.909341
# 2    891.388430    3.012397         66.466942        0.194215
# 3  31486.477982   17.476147        445.017431        1.317431
#
#   Days_since_enroll     Award
#                mean      mean
# 0       4060.013895  0.255319
# 1       4229.689560  0.901099
# 2       4843.239669  0.185950
# ...

# %%
# Plotting Clusters
plt.figure(figsize=(10, 5))  
plt.scatter(airline2['Clusters_4_ID'],airline2['Balance'], c=clusters_4.labels_)

# %% [markdown]
# ### Building cluster using k = 5

# %%
# Creating copies of datasets
airline3 = airline.copy()
airline_norm3 = airline_norm.copy()

# %%
# Cluster algorithm using K=5
clusters_5=KMeans(5,random_state=30).fit(airline_norm3)
clusters_5
# Out:
# KMeans(n_clusters=5, random_state=30)

# %%
clusters_5.labels_
# Out:
# array([0, 3, 0, ..., 4, 0, 3])

# %%
# Assigning clusters to the original dataset
airline3['Clusters_5_ID']=clusters_5.labels_
airline3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Computing the centroids for K=5 clusters with 11 variables
clusters_5.cluster_centers_
# Out:
# array([[9.87581993e-01, 3.39051837e-03, 3.51053916e-05, 3.03791237e-05,
#         3.02652033e-05, 9.01709733e-02, 1.53701634e-04, 6.66013521e-03,
#         2.09767345e-05, 7.53291184e-02, 3.94536689e-06],
#        [5.14758999e-01, 2.45703304e-03, 9.55752981e-05, 5.00781670e-05,
#         4.87710513e-05, 8.02358706e-01, 5.20472068e-04, 1.80244812e-02,
#         6.06430623e-05, 1.36539353e-01, 3.06234744e-05],
#        [4.14644791e-01, 1.30104261e-18, 2.28611980e-04, 2.27627266e-04,
#         2.27627266e-04, 1.50766683e-01, 5.97513433e-04, 7.35401490e-03,
#         2.84888383e-05, 8.48268382e-01, 3.91049405e-05],
#        [8.93103634e-01, 4.45303855e-03, 1.23796982e-04, 1.23612826e-04,
#         1.23612826e-04, 7.60122618e-02, 2.95169039e-04, 6.30476783e-03,
#         2.07480658e-05, 4.07515394e-01, 1.35161631e-05],
#        [8.91833807e-01, 2.00098101e-03, 5.80553278e-05, 3.01489923e-05,
#         2.94377607e-05, 4.20637046e-01, 4.04859493e-04, 7.68892416e-03,
# ...

# %%
# Grouping data by Clusters (K=5)
airline3.groupby('Clusters_5_ID').agg(['mean']).reset_index()
# Out:
#   Clusters_5_ID       Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                          mean        mean      mean      mean      mean
# 0             0  97404.121382  185.499533  1.604575  1.009337  1.001867
# 1             1  27526.798295  115.818182  3.247159  1.034091  1.071023
# 2             2   2415.576577    0.000000  1.009009  1.000000  1.000000
# 3             3  11768.858247   55.121134  1.005155  1.000000  1.000000
# 4             4  70743.739563  116.122266  3.135189  1.025845  1.019881
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0   9636.360411    9.704015        520.399627        1.565359
# 1  41812.809659   17.599432        676.107955        1.951705
# 2    850.189189    3.036036         48.612613        0.171171
# 3    984.778351    3.469072         93.216495        0.293814
# 4  32531.393638   17.626243        442.855865        1.312127
#
# ...

# %%
# Plotting Clusters
plt.figure(figsize=(10, 5))  
plt.scatter(airline3['Clusters_5_ID'],airline3['Balance'], c=clusters_5.labels_)

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# ### Importing libraries for DBSCAN & creating copy of dataset

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
# Normalizing heterogenous numerical data using standard scalar fit transform to dataset
airline4 = airline.copy()
airline_norm4 = StandardScaler().fit_transform(airline4)

# %% [markdown]
# ### Creating clusters

# %%
dbscan = DBSCAN(eps = 1, min_samples = 5).fit(airline_norm4)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
airline_norm4
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
# Making clusters column 
Clusters=pd.DataFrame(dbscan.labels_,columns=['clusters'])
Clusters
# Out:
#       clusters
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 3994         1
# 3995         1
# 3996         1
# 3997         0
# 3998         0
#
# [3999 rows x 1 columns]

# %%
# Adding clusters the to dataset
airline4['Clusters']=dbscan.labels_
airline4
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline4.groupby('Clusters').agg(['mean']).reset_index()
# Out:
#   Clusters        Balance   Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean         mean      mean      mean      mean
# 0       -1  184010.198556   947.731047  2.754513  1.059567  1.088448
# 1        0   53298.132385     4.695558  1.658042  1.000000  1.000000
# 2        1   61334.918573     9.830741  2.591034  1.000000  1.000000
# 3        2   34806.538462     0.000000  1.000000  2.000000  1.000000
# 4        3   38616.166667     0.000000  1.000000  3.000000  1.000000
# 5        4  164883.400000  1471.600000  1.000000  1.000000  1.000000
# 6        5   27113.888889  2475.444444  1.000000  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  40265.904332   22.375451       2194.700361        6.324910
# 1   9046.818025    8.468305        133.003881        0.422165
# 2  22886.188472   12.860018        286.425435        0.912168
# ...

# %%
# Plotting Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(airline4['Clusters'],airline4['Balance'], c=dbscan.labels_)

# %% [markdown]
# ### Inference

# %% [markdown]
# > Cluster 2 is having a lowest Balance mean however, cluster 0 is having a highest Balance mean
